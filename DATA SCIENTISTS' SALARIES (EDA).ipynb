# %% [markdown]
# Internship Task 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd()
# Out:
# '/Users/macbook'

# %%
data = pd.read_csv('/Users/macbook/Downloads/Data Scientist Salaries - EDA/ds_salaries.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
data.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
sns.set_palette('BuPu_r')
sns.set_style('whitegrid')

# %%
plt.figure(figsize=(10,8))
plt.title('Experience Level Frequency')
sns.countplot(data=data, x='experience_level')
plt.xlabel('Experience level')
plt.ylabel('Frequency');

# %%
plt.figure(figsize=(16,8))
plt.title('Job Title Distribution')
sns.countplot(data=data, x='job_title')
plt.xlabel('Job Title')
plt.ylabel('Frequency');

# %%
data['job_title'].value_counts()
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# ...

# %%
plt.figure(figsize=(10,8))
plt.title('Distribution of Employment Type ')
sns.countplot(data=data, x='employment_type')
plt.xlabel('Employment Type')
plt.ylabel('Frequency');

# %%
plt.figure(figsize=(10,8))
plt.title('Distribution of Company size')
sns.countplot(data=data, x='company_size')
plt.xlabel('Company Size')
plt.ylabel('Frequency');

# %%
plt.figure(figsize=(16,8))
plt.title('Distribution of Employee Residence')
sns.countplot(data=data, x='employee_residence')
plt.xlabel('Employee Residence')
plt.ylabel('Frequency');

# %%
data['employee_residence'].value_counts()
# Out:
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# FR     18
# ES     15
# GR     13
# JP      7
# PT      6
# BR      6
# PK      6
# NL      5
# PL      4
# IT      4
# RU      4
# AE      3
# AT      3
# VN      3
# TR      3
# AU      3
# RO      2
# BE      2
# SG      2
# SI      2
# DK      2
# HU      2
# NG      2
# MX      2
# BO      1
# MY      1
# TN      1
# IE      1
# DZ      1
# AR      1
# CZ      1
# JE      1
# LU      1
# PR      1
# RS      1
# EE      1
# CL      1
# HK      1
# KE      1
# MD      1
# CO      1
# IR      1
# CN      1
# MT      1
# UA      1
# IQ      1
# HN      1
# BG      1
# HR      1
# PH      1
# NZ      1
# CH      1
# Name: employee_residence, dtype: int64

# %%
data['company_location'].value_counts()
# Out:
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# BR      3
# AE      3
# MX      3
# AU      3
# TR      3
# DK      3
# IT      2
# CZ      2
# SI      2
# RU      2
# CH      2
# NG      2
# CN      2
# BE      2
# VN      1
# EE      1
# AS      1
# DZ      1
# MY      1
# MD      1
# KE      1
# SG      1
# CO      1
# IR      1
# CL      1
# MT      1
# IL      1
# UA      1
# IQ      1
# RO      1
# HR      1
# NZ      1
# HU      1
# HN      1
# IE      1
# Name: company_location, dtype: int64

# %%
plt.figure(figsize=(16,8))
plt.title('Distribution of Company Location')
sns.countplot(data=data, x='company_location')
plt.xlabel('Company Location')
plt.ylabel('Frequency');

# %%
plt.figure(figsize=(10,8))
plt.title('Distribution of Work Year')
sns.histplot(data=data, x='work_year')
plt.xlabel('Work Year')
plt.ylabel('Frequency');

# %%
plt.figure(figsize=(16,8))
plt.title('Visualization of Salary in USD')
sns.histplot(data=data, x='salary_in_usd')
plt.xlabel('Salary in USD')
plt.ylabel('Frequency');

# %%
plt.figure(figsize=(10,8))
plt.title('Distribution of Remote Ratio')
sns.histplot(data=data, x='remote_ratio')
plt.xlabel('Remote Ratio')
plt.ylabel('Frequency');

# %%
plt.figure(figsize=(16,8))
plt.title('Work Year VS Remote Ratio')
sns.boxplot(y=data['remote_ratio'], x=data['work_year']);

# %%
plt.figure(figsize=(10,8))
plt.title('Work Year VS Salary')
sns.scatterplot(y=data['salary'], x=data['work_year']);

# %%
plt.figure(figsize=(16,8))
plt.title('Level of Experience VS Employment Type')
sns.countplot(x='employment_type', data=data, hue= 'experience_level');

# %%
data['job_title'].value_counts().sort_values(ascending=False).head().plot(kind='bar')
# Out:
# Data Scientist               143
# Data Engineer                132
# Data Analyst                  97
# Machine Learning Engineer     41
# Research Scientist            16
# Name: job_title, dtype: int64

# %%
plt.figure(figsize=(16,8))
data['job_title'].value_counts().sort_values(ascending=False).head().plot(kind='bar')
plt.title('Top 3 Job Titles')
plt.ylabel('experience_level')
plt.xlabel('job_title');

# %%
plt.figure(figsize=(16,8))
plt.title('Level of Experience VS Job Title')
sns.countplot(hue='job_title', data=data, x= 'experience_level');

# %%
pd.crosstab(data['job_title'], data['experience_level'])
# Out:
# experience_level                          EN  EX  MI  SE
# job_title
# 3D Computer Vision Researcher              0   0   1   0
# AI Scientist                               4   0   2   1
# Analytics Engineer                         0   2   0   2
# Applied Data Scientist                     1   0   2   2
# Applied Machine Learning Scientist         1   0   3   0
# BI Data Analyst                            2   1   3   0
# Big Data Architect                         0   0   0   1
# Big Data Engineer                          3   0   3   2
# Business Data Analyst                      2   0   3   0
# Cloud Data Engineer                        0   0   1   1
# Computer Vision Engineer                   3   0   0   3
# Computer Vision Software Engineer          2   0   1   0
# Data Analyst                              12   2  29  54
# Data Analytics Engineer                    1   0   1   2
# Data Analytics Lead                        0   0   0   1
# ...

# %%
sns.heatmap(pd.crosstab(data['job_title'], data['experience_level']));

# %%
plt.figure(figsize=(10,8))
plt.title('Level of Experience VS Company Size')
sns.countplot(x='company_size', data=data, hue= 'experience_level');

# %%
plt.figure(figsize=(16,8))
plt.title('Level of Experience VS Company Location')
sns.countplot(hue='company_location', data=data, x= 'experience_level');

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='work_year',y='salary',data=data);
plt.title('Salary VS Work Year');

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='experience_level',y='salary',data=data);
plt.title('Salary VS Experience Level');

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='company_size',y='salary',data=data)
plt.title('Salary VS Company Size');

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='job_title', y='salary',data=data)
plt.title('Highest Salaries By Job Title');

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='company_location',y='salary',data=data)
plt.title('Salary VS Company Location');
